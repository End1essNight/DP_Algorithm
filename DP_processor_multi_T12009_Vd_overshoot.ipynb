# %%
from algorithms.algo_processor_T12009_SC2_VGI import multi_processor_vd_overshoot

# %%
output_folder = r'C:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD documents\Projects\T12009\dynamic'
output_name = 'T12009 SCW vd overshoot'
username = 'Feiyuan Yang'
input_folders = [
    r'Y:\TESTDATA\DP\2026\06\11',
    r'Y:\TESTDATA\DP\2026\06\25',
    r'Y:\TESTDATA\DP\2026\06\26',
]
comment_contains = 'CGD-IHHB308'

# %%
multi_processor_vd_overshoot(input_folders, output_folder, output_name, comment_contains, username)
# Out:
# 3.0
# Tek20260611T140731.tss processing is finished.
# 3.3499999999999943
# Tek20260611T140741.tss processing is finished.
# 3.3499999999999943
# Tek20260611T141217.tss processing is finished.
# 2.5999999999999943
# Tek20260611T141224.tss processing is finished.
# 2.1499999999999773
# Tek20260611T141639.tss processing is finished.
# 2.9499999999999886
# Tek20260611T141646.tss processing is finished.
# 2.549999999999983
# Tek20260611T145118.tss processing is finished.
# 3.3499999999999943
# Tek20260611T145125.tss processing is finished.
# 3.3499999999999943
# Tek20260611T145401.tss processing is finished.
# 3.1499999999999773
# Tek20260611T145409.tss processing is finished.
# 2.9499999999999886
# Tek20260611T145705.tss processing is finished.
# 2.75
# Tek20260611T145715.tss processing is finished.
# 3.1499999999999773
# Tek20260611T150013.tss processing is finished.
# 2.549999999999983
# Tek20260611T150020.tss processing is finished.
# 3.0
# ...
