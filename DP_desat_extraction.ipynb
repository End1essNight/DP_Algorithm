# %%
from P42016_desat.DESAT_algo_processor import desat_TOLL_process

# %%
output_folder = r'C:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD documents\Projects\P42016\data analysis'
output_name = 'TP-SW-108 KR16 Desat data extraction'
input_folders = [
    r'Y:\TESTDATA\DP\2025\12\12\06018012\Vd400_Id350_Vg10.8',
    r'Y:\TESTDATA\DP\2025\12\12\06018012\Vd400_Id350_Vg15',
    r'Y:\TESTDATA\DP\2025\12\12\06018012\Vd400_Id350_Vg20',
    r'Y:\TESTDATA\DP\2025\12\12\05023007\Vd400_Id350_Vg10.8',
    r'Y:\TESTDATA\DP\2025\12\12\05023007\Vd400_Id350_Vg15',
    r'Y:\TESTDATA\DP\2025\12\12\05023007\Vd400_Id350_Vg20',
    r'Y:\TESTDATA\DP\2025\12\16\05023007',
    r'Y:\TESTDATA\DP\2025\12\16\03008020',
    r'Y:\TESTDATA\DP\2025\12\16\05017012',
    r'Y:\TESTDATA\DP\2025\12\16\06018009',
    r'Y:\TESTDATA\DP\2026\01\29',
]
comment_contains = 'TP-SW-108 KR16 Desat'

# %%
desat_TOLL_process(input_folders, output_folder, output_name, comment_contains)
# Out:
# Tek20251212T134111.tss processing is finished.
# Tek20251212T140241.tss processing is finished.
# Tek20251212T134132.tss processing is finished.
# Tek20251212T140311.tss processing is finished.
# Tek20251212T134156.tss processing is finished.
# Tek20251212T140323.tss processing is finished.
# Tek20251212T144318.tss processing is finished.
# Tek20251212T144329.tss processing is finished.
# Tek20251212T144344.tss processing is finished.
# Tek20251216T085632.tss processing is finished.
# Tek20251216T085638.tss processing is finished.
# Tek20251216T085648.tss processing is finished.
# Tek20251216T100645.tss processing is finished.
# Tek20251216T101940.tss processing is finished.
# Tek20251216T100631.tss processing is finished.
# Tek20251216T101913.tss processing is finished.
# Tek20251216T100637.tss processing is finished.
# Tek20251216T101921.tss processing is finished.
# Tek20251216T123521.tss processing is finished.
# Tek20251216T125348.tss processing is finished.
# ...
