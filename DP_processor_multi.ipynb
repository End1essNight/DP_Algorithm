# %%
from algorithms.algo_processor import multi_processor_Rdson

# %%
output_folder = r'C:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD documents\Projects\R0003\data_analysis'
output_name = 'R0003 OctoGaN DP Socket test'
input_folders = [
    r'Y:\TESTDATA\DP\2025\08\01',
]
comment_contains = 'TN604003, TP-SW-100'
config_file = 'config_TV1.ini'

# %%
multi_processor_Rdson(input_folders, output_folder, output_name, comment_contains, config_file)
# Out:
# Tek20250801T130303.tss processing is finished.
# Tek20250801T102828.tss processing is finished.
# Tek20250801T103043.tss processing is finished.
# Tek20250801T101924.tss processing is finished.
# Tek20250801T130211.tss processing is finished.
# Tek20250801T102603.tss processing is finished.
# Tek20250801T102114.tss processing is finished.
# Tek20250801T143135.tss processing is finished.
# Tek20250801T130454.tss processing is finished.
# Tek20250801T144917.tss processing is finished.
# Tek20250801T143733.tss processing is finished.
# Tek20250801T125910.tss processing is finished.
# Tek20250801T093500.tss processing is finished.
# Tek20250801T102300.tss processing is finished.
# Tek20250801T143250.tss processing is finished.
# Tek20250801T103245.tss processing is finished.
# Tek20250801T093414.tss processing is finished.
# Tek20250801T142758.tss processing is finished.
# Tek20250801T143624.tss processing is finished.
# Tek20250801T143807.tss processing is finished.
# ...
