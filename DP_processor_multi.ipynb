# %%
from algorithms.algo_processor_v2 import multi_processor

# %%
output_folder = r'C:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD documents\Projects\T12009\dynamic'
output_name = 'T12009 SCW DP HB SROFF'
username = 'Feiyuan Yang'
input_folders = [
    r'Y:\TESTDATA\DP\2026\06\25',
    r'Y:\TESTDATA\DP\2026\06\26',
]
comment_contains = 'CGD-IHHB308, Rgon=RGoff'
config_file = 'config_T12009.ini'
parameters = {
    'time': True,       # Set as True if needed, False if not needed
    'energy': {
        'flag': True,   # Set as True if needed, False if not needed
        'auto_deskew': False,
        'manual_deskew': False,
        'deskew_time': 0, # Works only if manual_deskew is True, and auto_deskew is False
        'Lloop': None   # Specify None if not needed
    },
    'Qg': False,       # Set as True if needed, False if not needed
    'Rdson': {
        'flag': False,   # Set as True if needed, False if not needed
        't_avg': 100e-9,
        't_trigger': 0,
    },
    'dvdt': False,     # Set as True if needed, False if not needed
}

# %%
multi_processor(input_folders, output_folder, output_name, comment_contains, config_file, parameters, username)
# Out:
# Tek20260625T161428.tss processing is finished.
# Tek20260625T161807.tss processing is finished.
# Tek20260625T162128.tss processing is finished.
# Tek20260625T162549.tss processing is finished.
# Tek20260625T162848.tss processing is finished.
# Tek20260625T163221.tss processing is finished.
# Tek20260625T163647.tss processing is finished.
# Tek20260625T161325.tss processing is finished.
# Tek20260625T161707.tss processing is finished.
# Tek20260625T162019.tss processing is finished.
# Tek20260625T162438.tss processing is finished.
# Tek20260625T162729.tss processing is finished.
# Tek20260625T163030.tss processing is finished.
# Tek20260625T163517.tss processing is finished.
# Tek20260625T161332.tss processing is finished.
# Tek20260625T161713.tss processing is finished.
# Tek20260625T162026.tss processing is finished.
# Tek20260625T162446.tss processing is finished.
# Tek20260625T162736.tss processing is finished.
# Tek20260625T163036.tss processing is finished.
# ...
