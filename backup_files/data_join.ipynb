# %%
import os
import pandas as pd

# %%
folder = r'C:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD documents\Projects\R0003\data_analysis'
file1 = 'OctoGaN chip info.csv'
file2 = 'R0003 OctoGaN DP Socket test.csv'
df1 = pd.read_csv(os.path.join(folder, file1))
df2 = pd.read_csv(os.path.join(folder, file2))

# %%
result = pd.merge(df1, df2, on='Mark ID', how='outer')
output_path = os.path.join(folder, file2)
result.to_csv(output_path,index=False, header=True)
