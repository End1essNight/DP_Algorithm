# %%
from algorithms.algo_processor import single_processor

# %%
folder = r'Y:\TESTDATA\DP\2025\12'
tss_file = 'Tek20251202T155432.tss'
config_file = 'config_TV1.ini'

# %%
item = 'P42016'
single_processor(folder, tss_file, config_file, item=item)
# Out:
# didt_on (A/ns): 5.18787202381018, didt_off (A/ns): -15.760830965898807, is_at_mcgate-1.5 (A): 62.2625
# dVgi/dt_on (V/ns): 0.12033585114881491, dVgi/dt_off (V/ns): -0.28901808800046563
