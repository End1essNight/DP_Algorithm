# %%
from algorithms.algo_processor_v2 import multi_processor_no_json

# %%
output_folder = r'C:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD documents\Projects\R0004\dynamic'
output_name = 'R0004_test2'
username = 'Feiyuan Yang'
input_folders = [
    r'Y:\TESTDATA\DP\2026\06\10\2617A003VP',
]
config_file = 'config_T12009.ini'
parameters = {
    'time': True,       # Set as True if needed, False if not needed
    'energy': {
        'flag': True,   # Set as True if needed, False if not needed
        'auto_deskew': False,
        'manual_deskew': False,
        'deskew_time': 0,  # Works only if manual_deskew is True, and auto_deskew is False
        'lshunt': None     # Specify None if not needed
    },
    'Qg': False,       # Set as True if needed, False if not needed
    'Rdson': {
        'flag': False,   # Set as True if needed, False if not needed
        't_avg': 100e-9,
        't_trigger': 0,
        'inter_pulse_delay': 0,
        'pulse2_width': 0,
        'dead_time': 0
    },
    'dvdt': False,     # Set as True if needed, False if not needed
}

# %%
multi_processor_no_json(input_folders, output_folder, output_name, config_file, parameters, username)
# Out:
# Tek20260610T141213.tss processing is finished.
# Tek20260610T141222.tss processing is finished.
# Tek20260610T141201.tss processing is finished.
# Tek20260610T141207.tss processing is finished.
