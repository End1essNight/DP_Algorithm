# %%
from algorithms.algo_processor_T12009_SC2_VGI import multi_processor

# %%
output_folder = r'C:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD documents\Projects\T12009\dynamic'
output_name = 'T12009 SCW Rgon=Rgoff, PHM, RT Vgi and Ig data'
username = 'Feiyuan Yang'
input_folders = [
    r'Y:\TESTDATA\DP\2026\06\18',
]
comment_contains = 'Rgon=Rgoff, PHM, RT'

# %%
multi_processor(input_folders, output_folder, output_name, comment_contains, username)
# Out:
# Tek20260618T155731.tss processing is finished.
# Tek20260618T155827.tss processing is finished.
# Tek20260618T155735.tss processing is finished.
# Tek20260618T155831.tss processing is finished.
# Tek20260618T155739.tss processing is finished.
# Tek20260618T155834.tss processing is finished.
# Tek20260618T155743.tss processing is finished.
# Tek20260618T155839.tss processing is finished.
# Tek20260618T155747.tss processing is finished.
# Tek20260618T155843.tss processing is finished.
# Tek20260618T155752.tss processing is finished.
# Tek20260618T155848.tss processing is finished.
# Tek20260618T155716.tss processing is finished.
# Tek20260618T155812.tss processing is finished.
# Tek20260618T155719.tss processing is finished.
# Tek20260618T155816.tss processing is finished.
# Tek20260618T155723.tss processing is finished.
# Tek20260618T155819.tss processing is finished.
# Tek20260618T155727.tss processing is finished.
# Tek20260618T155823.tss processing is finished.
# ...
