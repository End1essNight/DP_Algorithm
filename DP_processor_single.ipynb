# %%
from algorithms.algo_processor_v2 import single_processor

# %%
folder = r'Y:\TESTDATA\DP\2026\06\11'
tss_file = 'Tek20260611T151320.tss'
config_file = 'config_T12009.ini'

# %%
item = 'time'
single_processor(folder, tss_file, config_file, item=item)
# Out:
# tdon (ns): 6.040652456047306, tf (ns): 11.22164785646144, tdoff (ns): 13.162330582062442, tr (ns): 4.351924677424276

# %%
item = 'energy'
auto_deskew = False
manual_deskew = True
deskew_time = 0
lshunt = None   # Specify None if not needed
single_processor(folder, tss_file, config_file, item=item, 
                 auto_deskew=auto_deskew, manual_deskew=manual_deskew, deskew_time=deskew_time, lshunt=lshunt)
# Out:
# Eon (uJ): 247.172001199994, Eoff (uJ): 52.828709399989265, Deskew time (ns): 0.0, Lloop: -2.977150641986749

# %%
item = 'qg'
single_processor(folder, tss_file, config_file, item=item)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 item = 'qg'
# ----> 2 single_processor(folder, tss_file, config_file, item=item)
#
# File c:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD_codes\DP_Algorithm-main\algorithms\algo_processor_v2.py:47, in single_processor(folder, tss_file, config_file, item, auto_deskew, manual_deskew, deskew_time, lshunt)
#      45     tss.figure_on_off_VV()
#      46 elif item == 'qg':
# ---> 47     qg = tss.gate_charge_extraction()
#      48     print(f'Qg_ON (nC): {qg[1]}, Qg_OFF (nC): {qg[0]}')
#      49     tss.figure_gate_waveform()
#
# File c:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD_codes\DP_Algorithm-main\algorithms\tss_process.py:140, in TSS_process.gate_charge_extraction(self)
#     138 def gate_charge_extraction(self):
#     139     if self.vg_channel is None or self.ig_channel is None:
# --> 140         raise Exception("Cannot find Vg or Ig channel!")
#     142     vg_edges = WFM_edge(self.vg_values, self.time, falling_edge_number=eval(self.qg_params['falling_edge_number']),
#     143                         rising_edge_number=eval(self.qg_params['rising_edge_number']),
#     144                         peak_width=eval(self.qg_params['peak_width']),
#     145                         peak_distance=eval(self.qg_params['peak_distance']),
#     146                         sigma=eval(self.qg_params['sigma']),
#     147                         margin_ratio=eval(self.qg_params['margin_ratio']),)
#     149     qgoff_thresh_1 = eval(self.qg_params['qgoff_thresh_1'])
#
# Exception: Cannot find Vg or Ig channel!
