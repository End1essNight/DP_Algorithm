# %%
from algorithms.algo_processor import single_processor

# %%
folder = r'Y:\TESTDATA\DP\2025\12'
tss_file = 'Tek20251210T153947.tss'
config_file = 'config_TEST.ini'

# %%
item = 'time'
single_processor(folder, tss_file, config_file, item=item)
# Out:
# tdon (ns): 46.25773227091658, tf (ns): 54.54324111238403, tdoff (ns): 703.7506802268782, tr (ns): 11.305578573523315

# %%
item = 'energy'
auto_deskew = False
manual_deskew = True
deskew_time = 0
lshunt = None   # Specify None if not needed
single_processor(folder, tss_file, config_file, item=item, 
                 auto_deskew=auto_deskew, manual_deskew=manual_deskew, deskew_time=deskew_time, lshunt=lshunt)
# Out:
# Eon (uJ): 729.6034807546869, Eoff (uJ): 64.00955368476536, Deskew time (ns): 0.0, Lloop: -6.31797039329118

# %%
item = 'qg'
single_processor(folder, tss_file, config_file, item=item)
# Out:
# Qg_ON (nC): 17.344946874999962, Qg_OFF (nC): -6.095135000000006

# %%
item = 'P42016'
single_processor(folder, tss_file, config_file, item=item)
# Out:
# dvdt_on (V/ns): -5.840332031249926, dvdt_off (V/ns): 30.68893432617262
# didt_on (A/ns): 1.8417338709677298, didt_off (A/ns): -3.4157764668369226, is_at_mcgate-1.5 (A): 30.54843749999999
