# %%
from algorithms.algo_processor import single_processor

# %%
folder = r'Y:\TESTDATA\DP\2026\03\12'
tss_file = 'Tek20260312T164646.tss'
config_file = 'config_TV3.ini'

# %%
item = 'time'
single_processor(folder, tss_file, config_file, item=item)
# Out:
# tdon (ns): 18.08138770049997, tf (ns): 8.18422895097908, tdoff (ns): 4.489317305331563, tr (ns): 3.0984156175260065

# %%
item = 'energy'
auto_deskew = False
manual_deskew = True
deskew_time = 0
lshunt = None   # Specify None if not needed
single_processor(folder, tss_file, config_file, item=item, 
                 auto_deskew=auto_deskew, manual_deskew=manual_deskew, deskew_time=deskew_time, lshunt=lshunt)
# Out:
# Eon (uJ): 145.33162971738247, Eoff (uJ): 11.445384401951353, Deskew time (ns): 0.0, Lloop: -26.27551612423512

# %%
item = 'qg'
single_processor(folder, tss_file, config_file, item=item)
# Out:
# Qg_ON (nC): 3.4048368750000724, Qg_OFF (nC): 0.22993874999992717
