# %%
from algorithms.algo_processor import single_processor

# %%
folder = r'Y:\TESTDATA\DP\2026\06\11'
tss_file = 'Tek20260610T092455.tss'
config_file = 'config_TV1.ini'

# %%
item = 'time'
single_processor(folder, tss_file, config_file, item=item)
# Out:
# tdon (ns): 12.58048021254462, tf (ns): 13.836277789165209, tdoff (ns): 11.631192176285788, tr (ns): 7.10910229731728

# %%
item = 'energy'
auto_deskew = False
manual_deskew = True
deskew_time = -0.5e-9
lshunt = None   # Specify None if not needed
single_processor(folder, tss_file, config_file, item=item, 
                 auto_deskew=auto_deskew, manual_deskew=manual_deskew, deskew_time=deskew_time, lshunt=lshunt)
# Out:
# Eon (uJ): 159.43037047812328, Eoff (uJ): 29.5153176828125, Deskew time (ns): -0.5, Lloop: -3.8569238128258636

# %%
item = 'qg'
single_processor(folder, tss_file, config_file, item=item)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 item = 'qg'
# ----> 2 single_processor(folder, tss_file, config_file, item=item)
#
# File c:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD_codes\DP_Algorithm-main\algorithms\algo_processor.py:43, in single_processor(folder, tss_file, config_file, item, auto_deskew, manual_deskew, deskew_time, lshunt)
#      41     tss.figure_on_off_VV()
#      42 elif item == 'qg':
# ---> 43     qg = tss.gate_charge_extraction()
#      44     print(f'Qg_ON (nC): {qg[1]}, Qg_OFF (nC): {qg[0]}')
#      45     tss.figure_gate_waveform()
#
# File c:\Users\FeiyuanYang\OneDrive - Cambridge GaN Devices Ltd\Documents\CGD_codes\DP_Algorithm-main\algorithms\tss_process.py:130, in TSS_process.gate_charge_extraction(self)
#     128 def gate_charge_extraction(self):
#     129     if self.vg_channel is None or self.ig_channel is None:
# --> 130         raise Exception("Cannot find Vg or Ig channel!")
#     132     vg_edges = WFM_edge(self.vg_values, self.time, falling_edge_number=eval(self.qg_params['falling_edge_number']),
#     133                         rising_edge_number=eval(self.qg_params['rising_edge_number']),
#     134                         peak_width=eval(self.qg_params['peak_width']),
#     135                         peak_distance=eval(self.qg_params['peak_distance']),
#     136                         sigma=eval(self.qg_params['sigma']),
#     137                         margin_ratio=eval(self.qg_params['margin_ratio']),)
#     139     qgoff_thresh_1 = eval(self.qg_params['qgoff_thresh_1'])
#
# Exception: Cannot find Vg or Ig channel!
